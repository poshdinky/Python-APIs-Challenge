# %% [markdown]
# # 1. The main objective

# %% [markdown]
# ### The main objective of the project is to build a series of scatter plots to visualize the weather of more than 500 cities all over the world of varying distance from the equator.

# %% [markdown]
# # 2. The prerequisites

# %% [markdown]
# ### In order to accomplish this, we'll be based on a simple Python Library called " citypy " to simplify the looking up process for some city names with geo-coordinates when it comes to dealing with social data, and also we'll use a fast and easy-to-work API called " OpenWeather Map".

# %% [markdown]
# # 3. Some helpful Analysis of the Data

# %% [markdown]
# ### Based on the cities tested, we can say that the weather becomes significantly warmer as one approaches the equator, which means the cities positioned at 0 degrees latitude experienced a smaller range of humidity than other cities, with a humidity no lower than 45%.
#
# ### There is no strong relationship between latitude and cloudiness. However, far more cities experienced 0% cloudiness as opposed to 100% cloudiness, outnumbering the latter by the dozens.
#
# ### There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %% [markdown]
# # Part_1 : WeatherPy

# %% [markdown]
# #### A. Installing the citipy Library in order to to determine city based on latitude and longitude

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\pc\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\pc\anaconda3\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# #### B. Importing the native libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
import datetime
import os
import pathlib

#Import The linear regression method to apply it on each relationship between temperature and latitude and so on
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Importy the citipy Library
from citipy import citipy

# %% [markdown]
# ## Using os, pathlib to get the current file.
#
#
# ### We will delete the element of the list that represents the current name file 'starter_code' and we will replace it ### by our output_data and Images

# %%
current_path = pathlib.Path().resolve()
current_path
# Out:
# WindowsPath('C:/Users/pc/Desktop/06-Python-APIs/Instructions/starter_code')

# %% [markdown]
# #### We will split our current file to folder path and file which is the name of our current file
#
# #### Folder_path will help us to uplod our output CSV file and images to any path we want.

# %%
folder_path, file = os.path.split(current_path)

# %%
print(f"Our global folders path is : {folder_path} and our current name file where we're executing this file is : {file}")
# Out:
# Our global folders path is : C:\Users\pc\Desktop\06-Python-APIs\Instructions and our current name file where we're executing this file is : starter_code

# %%
#Create today datetime Object
today_date = datetime.datetime.now()

# %%
# Range of latitudes and longitudes
latitude_range = (-90, 90)
longtitude_range = (-180, 180)

# %% [markdown]
# # Breakdown of Tasks

# %% [markdown]
# #### 1. Generate a random list of latitude, longtitude values using numpy, this random list is our cities list.

# %% [markdown]
# #### 2. Find nearest city using citypy for each latitude-longtitude coordinates combination.

# %%
# 1. Create a List of latitude_longtitude geographical coordinates that allow as to locate a point on the surface of the Earth.
lats_lngs_list = []

# Create a List of Cities
cities_list = []

# Create a list of random lats and lngs combinations with size of 1500
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs_list = zip(lats, lngs)

# 2. Identify nearest city for each lat, lng combination

for lat_lng in lats_lngs_list:
    city_name = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Check wether out nearest city is unique, it it's true, we'll add it to our cities list
    if city_name not in cities_list:
        cities_list.append(city_name)
        
# Print the city count to confirm sufficient count
print(f"The Size of our nearest cities list is : {len(cities_list)}")
# Out:
# The Size of our nearest cities list is : 616

# %%
cities_list
# Out:
# ['kapaa',
#  'cherskiy',
#  'barentsburg',
#  'beloha',
#  'cape town',
#  'ribeira grande',
#  'busselton',
#  'taolanaro',
#  'paamiut',
#  'codrington',
#  'bredasdorp',
#  'kumluca',
#  'castro',
#  'chokurdakh',
#  'licheng',
#  'seoul',
#  'torbay',
#  'nanortalik',
#  'esperance',
#  'whitehorse',
#  'kaeo',
#  'attawapiskat',
#  'rio gallegos',
#  'beckley',
#  'kieta',
#  'yenotayevka',
#  'puerto carreno',
#  'sentyabrskiy',
#  'blyth',
#  'cayenne',
#  'puerto baquerizo moreno',
#  'evensk',
#  'opuwo',
#  'badarwas',
#  'hithadhoo',
#  'sobolevo',
#  'camacupa',
#  'rikitea',
#  'biak',
#  'hermanus',
#  'akyab',
#  'vao',
#  'port hardy',
#  'ust-kuyga',
#  'ust-koksa',
#  'hobyo',
#  'kodiak',
#  'sovetskaya gavan',
#  'punta arenas',
#  'ushuaia',
#  'guymon',
#  'port lincoln',
#  'new norfolk',
#  'miranorte',
#  'vestmannaeyjar',
#  'vaini',
#  'pierre',
#  'tautira',
#  'roald',
#  'vaitupu',
#  'nikolskoye',
#  'butaritari',
#  'ilo',
#  'sitka',
#  'auki',
#  'jamestown',
#  'mount isa',
#  'puerto ayora',
#  'geraldton',
#  'eydhafushi',
#  'minab',
#  'norman wells',
#  'clyde river',
#  'acapulco',
#  'belushya guba',
#  'honningsvag',
#  'pemangkat',
#  'cidreira',
#  'saint george',
#  'kalmunai',
#  'pevek',
#  'olafsvik',
#  'alofi',
#  'albany',
#  'georgetown',
#  'aginskoye',
#  'srednekolymsk',
#  'pozo colorado',
#  'caloundra',
#  'atuona',
#  'novocheboksarsk',
#  'padang',
#  'mataura',
#  'yellowknife',
#  'saint-pierre',
#  'barcelos',
#  'sioux lookout',
#  'ilulissat',
#  'yumen',
#  'lebu',
#  'bluff',
#  'grand gaube',
#  'filingue',
#  'saldanha',
#  'hamilton',
#  'arlit',
#  'wanning',
#  'patti',
#  'yerbogachen',
#  'ngunguru',
#  'ormond beach',
#  'barrow',
#  'ancud',
#  'cabo san lucas',
#  'vakhrushi',
#  'saleaula',
#  'comodoro rivadavia',
#  'machilipatnam',
#  'kungurtug',
#  'mys shmidta',
#  'avarua',
#  'port elizabeth',
#  'ambulu',
#  'vernon',
#  'guilin',
#  'batagay',
#  'ponta do sol',
#  'deputatskiy',
#  'viligili',
#  'semey',
#  'coquimbo',
#  'saint-philippe',
#  'lagoa',
#  'san felipe',
#  'victoria',
#  'saskylakh',
#  'sorong',
#  'camacha',
#  'tiruvottiyur',
#  'ulladulla',
#  'khatanga',
#  'port alfred',
#  'hihifo',
#  'nizhneyansk',
#  'haines junction',
#  'plettenberg bay',
#  'bengkulu',
#  'chuy',
#  'yar-sale',
#  'hobart',
#  'tsementnyy',
#  'grand river south east',
#  'ostrovnoy',
#  'illoqqortoormiut',
#  'roanne',
#  'chernyshevskiy',
#  'lufilufi',
#  'hilo',
#  'kibala',
#  'bolobo',
#  'leningradskiy',
#  'bargal',
#  'tuatapere',
#  'dharchula',
#  'arraial do cabo',
#  'vila velha',
#  'hokitika',
#  'thompson',
#  'airai',
#  'vaitape',
#  'mombasa',
#  'puerto escondido',
#  'khonuu',
#  'pisco',
#  'santa cruz',
#  'romanovka',
#  'salalah',
#  'zhigansk',
#  'margate',
#  'rawson',
#  'pacific grove',
#  'along',
#  'port macquarie',
#  'vangaindrano',
#  'poya',
#  'galgani',
#  'mahebourg',
#  'torquay',
#  'cedar city',
#  'mocuba',
#  'assiniboia',
#  'iqaluit',
#  'vila',
#  'kahului',
#  'mar del plata',
#  'iranshahr',
#  'san julian',
#  'takoradi',
#  'vestmanna',
#  'lorengau',
#  'kloulklubed',
#  'luau',
#  'parry sound',
#  'dikson',
#  'dudinka',
#  'arawa',
#  'kabanjahe',
#  'siocon',
#  'promysla',
#  'sulangan',
#  'port blair',
#  'linjiang',
#  'severo-kurilsk',
#  'bastos',
#  'quatre cocos',
#  'oak creek',
#  'qaanaaq',
#  'martapura',
#  'praia',
#  'tasiilaq',
#  'cockburn town',
#  'mocambique',
#  'petropavlovsk-kamchatskiy',
#  'sao jose da coroa grande',
#  'fort nelson',
#  'molinella',
#  'virginia beach',
#  'hailey',
#  'lukovetskiy',
#  'high level',
#  'tsihombe',
#  'bani',
#  'buala',
#  'husavik',
#  'kushima',
#  'bambous virieux',
#  'belyy yar',
#  'itarema',
#  'popondetta',
#  'qasigiannguit',
#  'tuktoyaktuk',
#  'aswan',
#  'sedelnikovo',
#  'kozhevnikovo',
#  'dillon',
#  'ola',
#  'hambantota',
#  'verkhoyansk',
#  'dzhuryn',
#  'cabangahan',
#  'klyuchi',
#  'kendari',
#  'borba',
#  'caravelas',
#  'faanui',
#  'umzimvubu',
#  'usinsk',
#  'quelimane',
#  'babanusah',
#  'skhisma',
#  'nago',
#  'provideniya',
#  'namibe',
#  'vostok',
#  'nishihara',
#  'aklavik',
#  'tilichiki',
#  'inongo',
#  'flagstaff',
#  'peleduy',
#  'arjawinangun',
#  'porto novo',
#  'donegal',
#  'kavaratti',
#  'hirara',
#  'la ronge',
#  'corinto',
#  'lucan',
#  'naze',
#  'menongue',
#  'houma',
#  'amderma',
#  'kavieng',
#  'adrar',
#  'nanakuli',
#  'jalu',
#  'wegorzewo',
#  'kozhva',
#  'harrisonville',
#  'piacabucu',
#  'cunha',
#  'apple valley',
#  'eyl',
#  'kawana waters',
#  'korla',
#  'ibiapina',
#  'bathsheba',
#  'cerknica',
#  'talcahuano',
#  'ahipara',
#  'waingapu',
#  'victor harbor',
#  'bandar-e lengeh',
#  'kaitangata',
#  'sao felix do xingu',
#  'bay roberts',
#  'roma',
#  'newnan',
#  'manjacaze',
#  'sisimiut',
#  'portland',
#  'upernavik',
#  'berlevag',
#  'chengde',
#  'broome',
#  'antalaha',
#  'abatskoye',
#  'lublin',
#  'mananjary',
#  'wote',
#  'dujuma',
#  'rocha',
#  'ouallam',
#  'puerto narino',
#  'iquique',
#  'tiksi',
#  'ratnapura',
#  'elblag',
#  'bobonong',
#  'raudeberg',
#  'bonthe',
#  'skalistyy',
#  'inirida',
#  'tevriz',
#  'mashhad',
#  'voh',
#  'coihaique',
#  'conceicao do araguaia',
#  'kapit',
#  'claveria',
#  'bodaybo',
#  'hauterive',
#  'meulaboh',
#  'natchez',
#  'igarka',
#  'constitucion',
#  'sinnamary',
#  'jacksonville beach',
#  'malinovoye ozero',
#  'souillac',
#  'utiroa',
#  'ruatoria',
#  'leninskoye',
#  'labutta',
#  'moramanga',
#  'riachao das neves',
#  'zabaykalsk',
#  'goldenrod',
#  'gat',
#  'tecolutla',
#  'port augusta',
#  'kirkland lake',
#  'vila franca do campo',
#  'talwara',
#  'san cristobal',
#  'katsuura',
#  'doctor pedro p. pena',
#  'sladkovo',
#  'poladpur',
#  'solotvyn',
#  'lovozero',
#  'cairns',
#  'businga',
#  'jumla',
#  'dakar',
#  'galveston',
#  'nobres',
#  'longyearbyen',
#  'zatoka',
#  'marcona',
#  'fairbanks',
#  'batetskiy',
#  'laguna',
#  'the valley',
#  'grindavik',
#  'la palma',
#  'el seibo',
#  'pangnirtung',
#  'hovd',
#  'chantada',
#  'sumbawa',
#  'saint anthony',
#  'may pen',
#  'shenjiamen',
#  'fortuna',
#  'sao filipe',
#  'perevoz',
#  'prado',
#  'kattivakkam',
#  'mareeba',
#  'shingu',
#  'wilmington',
#  'luderitz',
#  'ariquemes',
#  'letlhakane',
#  'mildura',
#  'buraydah',
#  'finschhafen',
#  'steinbach',
#  'pokrovsk-uralskiy',
#  'makakilo city',
#  'namatanai',
#  'cloquet',
#  'pitimbu',
#  'russell',
#  'hasaki',
#  'rafaela',
#  'port hawkesbury',
#  'dryden',
#  'kuva',
#  'borovskoy',
#  'puerto colombia',
#  'turukhansk',
#  'ambunti',
#  'tomatlan',
#  'borogontsy',
#  'havre-saint-pierre',
#  'invermere',
#  'aflu',
#  'saint-augustin',
#  'maniitsoq',
#  'tahe',
#  'palabuhanratu',
#  'westerland',
#  'elverum',
#  'nioro',
#  'east london',
#  'tazovskiy',
#  'mount gambier',
#  'tura',
#  'umm kaddadah',
#  'umm lajj',
#  'blagoyevo',
#  'westport',
#  'kuche',
#  'mahon',
#  'abu dhabi',
#  'baruun-urt',
#  'beian',
#  'madison',
#  'nuuk',
#  'french harbor',
#  'balikpapan',
#  'hutchinson',
#  'kiama',
#  'priiskovyy',
#  'krasnoarmeysk',
#  'peniche',
#  'nelson',
#  'huanren',
#  'mehamn',
#  'flinders',
#  'kutum',
#  'zheshart',
#  'jawhar',
#  'vardo',
#  'villarrica',
#  'sault sainte marie',
#  'graaff-reinet',
#  'lolua',
#  'abu kamal',
#  'egvekinot',
#  'matagami',
#  'port-gentil',
#  'beringovskiy',
#  'lebyazhye',
#  'kikwit',
#  'maracaibo',
#  'san jose',
#  'udachnyy',
#  'hami',
#  'ocos',
#  'kualakapuas',
#  'sao joao da barra',
#  'berdigestyakh',
#  'fagernes',
#  'uyuni',
#  'campo de criptana',
#  'point pedro',
#  'bolungarvik',
#  'ekibastuz',
#  'carballo',
#  'sambava',
#  'san patricio',
#  'inverell',
#  'alice springs',
#  'mrirt',
#  'cadereyta',
#  'sangueya',
#  'kununurra',
#  'maralal',
#  'cuamba',
#  'vila do maio',
#  'guerrero negro',
#  'lakatoro',
#  'malpe',
#  'nabire',
#  'dingle',
#  'bulgan',
#  'anadyr',
#  'tumannyy',
#  'lompoc',
#  'el transito',
#  'almora',
#  'anzio',
#  'huitziltepec',
#  'chapais',
#  'hongjiang',
#  'ribeira brava',
#  'qaqortoq',
#  'havelock',
#  'kemijarvi',
#  'sola',
#  'ust-ilimsk',
#  'reforma',
#  'ambagarh chauki',
#  'samusu',
#  'lae',
#  'vadso',
#  'cristobal obregon',
#  'praia da vitoria',
#  'nome',
#  'sundargarh',
#  'vallentuna',
#  'marquette',
#  'oga',
#  'gemena',
#  'new waterford',
#  'dali',
#  'pemagatsel',
#  'joshimath',
#  'muros',
#  'batagay-alyta',
#  'outjo',
#  'half moon bay',
#  'keuruu',
#  'caucaia',
#  'chara',
#  'carutapera',
#  'tynda',
#  'mancora',
#  'erenhot',
#  'morgan city',
#  'mitsamiouli',
#  'narasannapeta',
#  'kivsharivka',
#  'buchanan',
#  'lakhipur',
#  'tiarei',
#  'caraballeda',
#  'toliary',
#  'monrovia',
#  'nara',
#  'simao',
#  'palmer',
#  'panarukan',
#  'lavrentiya',
#  'kodinsk',
#  'huarmey',
#  'tagusao',
#  'hegra',
#  'pavlogradka',
#  'xai-xai',
#  'robertson',
#  'pingliang',
#  'zolotinka',
#  'mgandu',
#  'punta alta',
#  'udaipur',
#  'borgarnes',
#  'bethel',
#  'harnosand',
#  'point fortin',
#  'san carlos de bariloche',
#  'flin flon',
#  'omsukchan',
#  'batala',
#  'puri',
#  'hofn',
#  'narsaq',
#  'somerset',
#  'mosetse',
#  'wahiawa',
#  'bulungu',
#  'lumeje',
#  'strezhevoy',
#  'wageningen',
#  'kuusamo',
#  'kovernino',
#  'brae',
#  'reo',
#  'labuhan',
#  'pontiac',
#  'sistranda',
#  'umba',
#  'ketchenery',
#  'richards bay',
#  'cumaribo',
#  'dhidhdhoo',
#  'nosy varika',
#  'marondera',
#  'shymkent',
#  'walvis bay',
#  'krasnoselkup',
#  'soyo',
#  'mirnyy']

# %% [markdown]
# #### 3. Perform weather API call using imported API key to perform a weather check on each city, and include a print log of each city as it's being processed (with the city number and city name).

# %%
#API_Call infos
weather_url = f"https://api.openweathermap.org/data/2.5/weather?"
city_weather_responses = []

#Initialize the lists for the DataFrame
records = 1
sets = 1
city_name = []
Lat = [] 
Lng = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_Speed = []
Country = []
Date = []

print("Beginning Data Retrieval\n")
print("--------------------------------------------")

#Looping through the cities and perform a request for data on each one
for city in cities_list:

    #This condition allows us to create a 50 record for each set, then for each unique set, we'll display all the 50 cities informations. 
    if records == 51:
        sets = sets + 1
        records = 1
    
    #The full link of the weather API of each city
    query_url = f"{weather_url}q={city}&appid={weather_api_key}"
    
    # Get back a JSON infos for each city by the request librabry that will access the website to bring back the necessary infos
    city_weather_response = requests.get(query_url).json()  
    
    #Making sure the code doesn't break  
    try:
        print(f"Processing Record {records} of set {sets} | {city}")
        print(f"To get the XML File of all weather informations of the city named : [ {city} ] is by clicking on the link: {query_url}")
        print('-------------------------------------------- \n')
        
        # Insert our amm different city Names into a list that we'll use it after for out Df.
        city_name.append(city_weather_response['name'])
        
        #Lists to hold reponse info
        Lat.append(city_weather_response['coord']['lat'])
        Lng.append(city_weather_response['coord']['lon'])
        Max_Temp.append(city_weather_response['main']['temp_max'])
        Humidity.append(city_weather_response['main']['humidity'])
        Cloudiness.append(city_weather_response['clouds']['all'])
        Wind_Speed.append(city_weather_response['wind']['speed'])
        Country.append(city_weather_response['sys']['country'])
        Date.append(city_weather_response['dt'])
        
        # Insert each city weather on the city_weather_responses list
        city_weather_responses.append(city_weather_response)
        
        #Increment the number of each set so it'll be 50 record of each set
        records = records + 1
    
    except (NameError, KeyError) as e:
        print(f"The City named [ { city } ] was not found. Skipping... ") 
        pass

    
print('-------------------------------------------- \n Data Retrieval Complete \n-------------------------------------------- ')
# Out:
# Beginning Data Retrieval
#
# --------------------------------------------
# Processing Record 1 of set 1 | kapaa
# To get the XML File of all weather informations of the city named : [ kapaa ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 2 of set 1 | cherskiy
# To get the XML File of all weather informations of the city named : [ cherskiy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 3 of set 1 | barentsburg
# To get the XML File of all weather informations of the city named : [ barentsburg ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ barentsburg ] was not found. Skipping...
# Processing Record 3 of set 1 | beloha
# To get the XML File of all weather informations of the city named : [ beloha ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=beloha&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 4 of set 1 | cape town
# To get the XML File of all weather informations of the city named : [ cape town ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=cape town&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 5 of set 1 | ribeira grande
# To get the XML File of all weather informations of the city named : [ ribeira grande ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 6 of set 1 | busselton
# To get the XML File of all weather informations of the city named : [ busselton ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=busselton&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 7 of set 1 | taolanaro
# To get the XML File of all weather informations of the city named : [ taolanaro ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ taolanaro ] was not found. Skipping...
# Processing Record 7 of set 1 | paamiut
# To get the XML File of all weather informations of the city named : [ paamiut ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=paamiut&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 8 of set 1 | codrington
# To get the XML File of all weather informations of the city named : [ codrington ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=codrington&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 9 of set 1 | bredasdorp
# To get the XML File of all weather informations of the city named : [ bredasdorp ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 10 of set 1 | kumluca
# To get the XML File of all weather informations of the city named : [ kumluca ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kumluca&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 11 of set 1 | castro
# To get the XML File of all weather informations of the city named : [ castro ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=castro&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 12 of set 1 | chokurdakh
# To get the XML File of all weather informations of the city named : [ chokurdakh ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 13 of set 1 | licheng
# To get the XML File of all weather informations of the city named : [ licheng ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=licheng&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 14 of set 1 | seoul
# To get the XML File of all weather informations of the city named : [ seoul ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=seoul&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 15 of set 1 | torbay
# To get the XML File of all weather informations of the city named : [ torbay ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=torbay&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 16 of set 1 | nanortalik
# To get the XML File of all weather informations of the city named : [ nanortalik ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=nanortalik&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 17 of set 1 | esperance
# To get the XML File of all weather informations of the city named : [ esperance ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=esperance&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 18 of set 1 | whitehorse
# To get the XML File of all weather informations of the city named : [ whitehorse ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=whitehorse&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 19 of set 1 | kaeo
# To get the XML File of all weather informations of the city named : [ kaeo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kaeo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 20 of set 1 | attawapiskat
# To get the XML File of all weather informations of the city named : [ attawapiskat ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=attawapiskat&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ attawapiskat ] was not found. Skipping...
# Processing Record 20 of set 1 | rio gallegos
# To get the XML File of all weather informations of the city named : [ rio gallegos ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=rio gallegos&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 21 of set 1 | beckley
# To get the XML File of all weather informations of the city named : [ beckley ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=beckley&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 22 of set 1 | kieta
# To get the XML File of all weather informations of the city named : [ kieta ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kieta&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 23 of set 1 | yenotayevka
# To get the XML File of all weather informations of the city named : [ yenotayevka ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=yenotayevka&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 24 of set 1 | puerto carreno
# To get the XML File of all weather informations of the city named : [ puerto carreno ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=puerto carreno&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
# Processing Record 25 of set 1 | sentyabrskiy
# To get the XML File of all weather informations of the city named : [ sentyabrskiy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ sentyabrskiy ] was not found. Skipping...
# Processing Record 25 of set 1 | blyth
# To get the XML File of all weather informations of the city named : [ blyth ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=blyth&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 26 of set 1 | cayenne
# To get the XML File of all weather informations of the city named : [ cayenne ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=cayenne&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 27 of set 1 | puerto baquerizo moreno
# To get the XML File of all weather informations of the city named : [ puerto baquerizo moreno ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=puerto baquerizo moreno&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 28 of set 1 | evensk
# To get the XML File of all weather informations of the city named : [ evensk ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=evensk&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 29 of set 1 | opuwo
# To get the XML File of all weather informations of the city named : [ opuwo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=opuwo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 30 of set 1 | badarwas
# To get the XML File of all weather informations of the city named : [ badarwas ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=badarwas&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 31 of set 1 | hithadhoo
# To get the XML File of all weather informations of the city named : [ hithadhoo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 32 of set 1 | sobolevo
# To get the XML File of all weather informations of the city named : [ sobolevo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=sobolevo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 33 of set 1 | camacupa
# To get the XML File of all weather informations of the city named : [ camacupa ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=camacupa&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 34 of set 1 | rikitea
# To get the XML File of all weather informations of the city named : [ rikitea ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 35 of set 1 | biak
# To get the XML File of all weather informations of the city named : [ biak ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=biak&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 36 of set 1 | hermanus
# To get the XML File of all weather informations of the city named : [ hermanus ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 37 of set 1 | akyab
# To get the XML File of all weather informations of the city named : [ akyab ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=akyab&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 38 of set 1 | vao
# To get the XML File of all weather informations of the city named : [ vao ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=vao&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 39 of set 1 | port hardy
# To get the XML File of all weather informations of the city named : [ port hardy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=port hardy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 40 of set 1 | ust-kuyga
# To get the XML File of all weather informations of the city named : [ ust-kuyga ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ust-kuyga&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 41 of set 1 | ust-koksa
# To get the XML File of all weather informations of the city named : [ ust-koksa ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ust-koksa&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 42 of set 1 | hobyo
# To get the XML File of all weather informations of the city named : [ hobyo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hobyo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 43 of set 1 | kodiak
# To get the XML File of all weather informations of the city named : [ kodiak ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 44 of set 1 | sovetskaya gavan
# To get the XML File of all weather informations of the city named : [ sovetskaya gavan ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=sovetskaya gavan&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 45 of set 1 | punta arenas
# To get the XML File of all weather informations of the city named : [ punta arenas ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 46 of set 1 | ushuaia
# To get the XML File of all weather informations of the city named : [ ushuaia ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 47 of set 1 | guymon
# To get the XML File of all weather informations of the city named : [ guymon ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=guymon&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 48 of set 1 | port lincoln
# To get the XML File of all weather informations of the city named : [ port lincoln ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=port lincoln&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 49 of set 1 | new norfolk
# To get the XML File of all weather informations of the city named : [ new norfolk ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 50 of set 1 | miranorte
# To get the XML File of all weather informations of the city named : [ miranorte ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=miranorte&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ miranorte ] was not found. Skipping...
# Processing Record 50 of set 1 | vestmannaeyjar
# To get the XML File of all weather informations of the city named : [ vestmannaeyjar ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
# Processing Record 1 of set 2 | vaini
# To get the XML File of all weather informations of the city named : [ vaini ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=vaini&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 2 of set 2 | pierre
# To get the XML File of all weather informations of the city named : [ pierre ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=pierre&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 3 of set 2 | tautira
# To get the XML File of all weather informations of the city named : [ tautira ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=tautira&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 4 of set 2 | roald
# To get the XML File of all weather informations of the city named : [ roald ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=roald&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 5 of set 2 | vaitupu
# To get the XML File of all weather informations of the city named : [ vaitupu ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=vaitupu&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ vaitupu ] was not found. Skipping...
# Processing Record 5 of set 2 | nikolskoye
# To get the XML File of all weather informations of the city named : [ nikolskoye ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 6 of set 2 | butaritari
# To get the XML File of all weather informations of the city named : [ butaritari ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 7 of set 2 | ilo
# To get the XML File of all weather informations of the city named : [ ilo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ilo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 8 of set 2 | sitka
# To get the XML File of all weather informations of the city named : [ sitka ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=sitka&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 9 of set 2 | auki
# To get the XML File of all weather informations of the city named : [ auki ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=auki&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 10 of set 2 | jamestown
# To get the XML File of all weather informations of the city named : [ jamestown ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 11 of set 2 | mount isa
# To get the XML File of all weather informations of the city named : [ mount isa ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=mount isa&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 12 of set 2 | puerto ayora
# To get the XML File of all weather informations of the city named : [ puerto ayora ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 13 of set 2 | geraldton
# To get the XML File of all weather informations of the city named : [ geraldton ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=geraldton&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 14 of set 2 | eydhafushi
# To get the XML File of all weather informations of the city named : [ eydhafushi ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=eydhafushi&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 15 of set 2 | minab
# To get the XML File of all weather informations of the city named : [ minab ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=minab&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 16 of set 2 | norman wells
# To get the XML File of all weather informations of the city named : [ norman wells ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=norman wells&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 17 of set 2 | clyde river
# To get the XML File of all weather informations of the city named : [ clyde river ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=clyde river&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 18 of set 2 | acapulco
# To get the XML File of all weather informations of the city named : [ acapulco ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=acapulco&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 19 of set 2 | belushya guba
# To get the XML File of all weather informations of the city named : [ belushya guba ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ belushya guba ] was not found. Skipping...
# Processing Record 19 of set 2 | honningsvag
# To get the XML File of all weather informations of the city named : [ honningsvag ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=honningsvag&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 20 of set 2 | pemangkat
# To get the XML File of all weather informations of the city named : [ pemangkat ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=pemangkat&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 21 of set 2 | cidreira
# To get the XML File of all weather informations of the city named : [ cidreira ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 22 of set 2 | saint george
# To get the XML File of all weather informations of the city named : [ saint george ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=saint george&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 23 of set 2 | kalmunai
# To get the XML File of all weather informations of the city named : [ kalmunai ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kalmunai&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 24 of set 2 | pevek
# To get the XML File of all weather informations of the city named : [ pevek ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=pevek&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 25 of set 2 | olafsvik
# To get the XML File of all weather informations of the city named : [ olafsvik ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=olafsvik&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 26 of set 2 | alofi
# To get the XML File of all weather informations of the city named : [ alofi ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=alofi&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
# Processing Record 27 of set 2 | albany
# To get the XML File of all weather informations of the city named : [ albany ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=albany&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 28 of set 2 | georgetown
# To get the XML File of all weather informations of the city named : [ georgetown ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 29 of set 2 | aginskoye
# To get the XML File of all weather informations of the city named : [ aginskoye ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=aginskoye&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 30 of set 2 | srednekolymsk
# To get the XML File of all weather informations of the city named : [ srednekolymsk ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=srednekolymsk&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 31 of set 2 | pozo colorado
# To get the XML File of all weather informations of the city named : [ pozo colorado ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=pozo colorado&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 32 of set 2 | caloundra
# To get the XML File of all weather informations of the city named : [ caloundra ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=caloundra&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 33 of set 2 | atuona
# To get the XML File of all weather informations of the city named : [ atuona ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=atuona&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 34 of set 2 | novocheboksarsk
# To get the XML File of all weather informations of the city named : [ novocheboksarsk ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=novocheboksarsk&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 35 of set 2 | padang
# To get the XML File of all weather informations of the city named : [ padang ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=padang&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 36 of set 2 | mataura
# To get the XML File of all weather informations of the city named : [ mataura ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=mataura&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 37 of set 2 | yellowknife
# To get the XML File of all weather informations of the city named : [ yellowknife ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 38 of set 2 | saint-pierre
# To get the XML File of all weather informations of the city named : [ saint-pierre ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=saint-pierre&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 39 of set 2 | barcelos
# To get the XML File of all weather informations of the city named : [ barcelos ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=barcelos&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 40 of set 2 | sioux lookout
# To get the XML File of all weather informations of the city named : [ sioux lookout ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=sioux lookout&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 41 of set 2 | ilulissat
# To get the XML File of all weather informations of the city named : [ ilulissat ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ilulissat&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 42 of set 2 | yumen
# To get the XML File of all weather informations of the city named : [ yumen ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=yumen&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 43 of set 2 | lebu
# To get the XML File of all weather informations of the city named : [ lebu ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=lebu&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 44 of set 2 | bluff
# To get the XML File of all weather informations of the city named : [ bluff ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=bluff&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 45 of set 2 | grand gaube
# To get the XML File of all weather informations of the city named : [ grand gaube ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=grand gaube&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 46 of set 2 | filingue
# To get the XML File of all weather informations of the city named : [ filingue ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=filingue&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 47 of set 2 | saldanha
# To get the XML File of all weather informations of the city named : [ saldanha ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=saldanha&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 48 of set 2 | hamilton
# To get the XML File of all weather informations of the city named : [ hamilton ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hamilton&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 49 of set 2 | arlit
# To get the XML File of all weather informations of the city named : [ arlit ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=arlit&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 50 of set 2 | wanning
# To get the XML File of all weather informations of the city named : [ wanning ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=wanning&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 1 of set 3 | patti
# To get the XML File of all weather informations of the city named : [ patti ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=patti&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 2 of set 3 | yerbogachen
# To get the XML File of all weather informations of the city named : [ yerbogachen ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=yerbogachen&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 3 of set 3 | ngunguru
# To get the XML File of all weather informations of the city named : [ ngunguru ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ngunguru&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 4 of set 3 | ormond beach
# To get the XML File of all weather informations of the city named : [ ormond beach ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ormond beach&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
# Processing Record 5 of set 3 | barrow
# To get the XML File of all weather informations of the city named : [ barrow ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=barrow&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 6 of set 3 | ancud
# To get the XML File of all weather informations of the city named : [ ancud ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ancud&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 7 of set 3 | cabo san lucas
# To get the XML File of all weather informations of the city named : [ cabo san lucas ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 8 of set 3 | vakhrushi
# To get the XML File of all weather informations of the city named : [ vakhrushi ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=vakhrushi&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 9 of set 3 | saleaula
# To get the XML File of all weather informations of the city named : [ saleaula ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ saleaula ] was not found. Skipping...
# Processing Record 9 of set 3 | comodoro rivadavia
# To get the XML File of all weather informations of the city named : [ comodoro rivadavia ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 10 of set 3 | machilipatnam
# To get the XML File of all weather informations of the city named : [ machilipatnam ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=machilipatnam&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 11 of set 3 | kungurtug
# To get the XML File of all weather informations of the city named : [ kungurtug ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kungurtug&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 12 of set 3 | mys shmidta
# To get the XML File of all weather informations of the city named : [ mys shmidta ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=mys shmidta&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ mys shmidta ] was not found. Skipping...
# Processing Record 12 of set 3 | avarua
# To get the XML File of all weather informations of the city named : [ avarua ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=avarua&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 13 of set 3 | port elizabeth
# To get the XML File of all weather informations of the city named : [ port elizabeth ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 14 of set 3 | ambulu
# To get the XML File of all weather informations of the city named : [ ambulu ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ambulu&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 15 of set 3 | vernon
# To get the XML File of all weather informations of the city named : [ vernon ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=vernon&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 16 of set 3 | guilin
# To get the XML File of all weather informations of the city named : [ guilin ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=guilin&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 17 of set 3 | batagay
# To get the XML File of all weather informations of the city named : [ batagay ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=batagay&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 18 of set 3 | ponta do sol
# To get the XML File of all weather informations of the city named : [ ponta do sol ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ponta do sol&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 19 of set 3 | deputatskiy
# To get the XML File of all weather informations of the city named : [ deputatskiy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=deputatskiy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 20 of set 3 | viligili
# To get the XML File of all weather informations of the city named : [ viligili ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=viligili&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ viligili ] was not found. Skipping...
# Processing Record 20 of set 3 | semey
# To get the XML File of all weather informations of the city named : [ semey ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=semey&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 21 of set 3 | coquimbo
# To get the XML File of all weather informations of the city named : [ coquimbo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=coquimbo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 22 of set 3 | saint-philippe
# To get the XML File of all weather informations of the city named : [ saint-philippe ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 23 of set 3 | lagoa
# To get the XML File of all weather informations of the city named : [ lagoa ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=lagoa&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 24 of set 3 | san felipe
# To get the XML File of all weather informations of the city named : [ san felipe ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=san felipe&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 25 of set 3 | victoria
# To get the XML File of all weather informations of the city named : [ victoria ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=victoria&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 26 of set 3 | saskylakh
# To get the XML File of all weather informations of the city named : [ saskylakh ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 27 of set 3 | sorong
# To get the XML File of all weather informations of the city named : [ sorong ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=sorong&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 28 of set 3 | camacha
# To get the XML File of all weather informations of the city named : [ camacha ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=camacha&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
# Processing Record 29 of set 3 | tiruvottiyur
# To get the XML File of all weather informations of the city named : [ tiruvottiyur ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=tiruvottiyur&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ tiruvottiyur ] was not found. Skipping...
# Processing Record 29 of set 3 | ulladulla
# To get the XML File of all weather informations of the city named : [ ulladulla ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ulladulla&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 30 of set 3 | khatanga
# To get the XML File of all weather informations of the city named : [ khatanga ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 31 of set 3 | port alfred
# To get the XML File of all weather informations of the city named : [ port alfred ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 32 of set 3 | hihifo
# To get the XML File of all weather informations of the city named : [ hihifo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hihifo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ hihifo ] was not found. Skipping...
# Processing Record 32 of set 3 | nizhneyansk
# To get the XML File of all weather informations of the city named : [ nizhneyansk ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ nizhneyansk ] was not found. Skipping...
# Processing Record 32 of set 3 | haines junction
# To get the XML File of all weather informations of the city named : [ haines junction ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=haines junction&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 33 of set 3 | plettenberg bay
# To get the XML File of all weather informations of the city named : [ plettenberg bay ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=plettenberg bay&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 34 of set 3 | bengkulu
# To get the XML File of all weather informations of the city named : [ bengkulu ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 35 of set 3 | chuy
# To get the XML File of all weather informations of the city named : [ chuy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=chuy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 36 of set 3 | yar-sale
# To get the XML File of all weather informations of the city named : [ yar-sale ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=yar-sale&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 37 of set 3 | hobart
# To get the XML File of all weather informations of the city named : [ hobart ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hobart&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 38 of set 3 | tsementnyy
# To get the XML File of all weather informations of the city named : [ tsementnyy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=tsementnyy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 39 of set 3 | grand river south east
# To get the XML File of all weather informations of the city named : [ grand river south east ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=grand river south east&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ grand river south east ] was not found. Skipping...
# Processing Record 39 of set 3 | ostrovnoy
# To get the XML File of all weather informations of the city named : [ ostrovnoy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 40 of set 3 | illoqqortoormiut
# To get the XML File of all weather informations of the city named : [ illoqqortoormiut ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ illoqqortoormiut ] was not found. Skipping...
# Processing Record 40 of set 3 | roanne
# To get the XML File of all weather informations of the city named : [ roanne ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=roanne&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 41 of set 3 | chernyshevskiy
# To get the XML File of all weather informations of the city named : [ chernyshevskiy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=chernyshevskiy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 42 of set 3 | lufilufi
# To get the XML File of all weather informations of the city named : [ lufilufi ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=lufilufi&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 43 of set 3 | hilo
# To get the XML File of all weather informations of the city named : [ hilo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hilo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 44 of set 3 | kibala
# ...
#
# Processing Record 18 of set 11 | simao
# To get the XML File of all weather informations of the city named : [ simao ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=simao&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 19 of set 11 | palmer
# To get the XML File of all weather informations of the city named : [ palmer ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=palmer&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 20 of set 11 | panarukan
# To get the XML File of all weather informations of the city named : [ panarukan ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=panarukan&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 21 of set 11 | lavrentiya
# To get the XML File of all weather informations of the city named : [ lavrentiya ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=lavrentiya&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 22 of set 11 | kodinsk
# To get the XML File of all weather informations of the city named : [ kodinsk ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kodinsk&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 23 of set 11 | huarmey
# To get the XML File of all weather informations of the city named : [ huarmey ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=huarmey&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 24 of set 11 | tagusao
# To get the XML File of all weather informations of the city named : [ tagusao ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=tagusao&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 25 of set 11 | hegra
# To get the XML File of all weather informations of the city named : [ hegra ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hegra&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 26 of set 11 | pavlogradka
# To get the XML File of all weather informations of the city named : [ pavlogradka ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=pavlogradka&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 27 of set 11 | xai-xai
# To get the XML File of all weather informations of the city named : [ xai-xai ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=xai-xai&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 28 of set 11 | robertson
# To get the XML File of all weather informations of the city named : [ robertson ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=robertson&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 29 of set 11 | pingliang
# To get the XML File of all weather informations of the city named : [ pingliang ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=pingliang&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 30 of set 11 | zolotinka
# To get the XML File of all weather informations of the city named : [ zolotinka ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=zolotinka&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ zolotinka ] was not found. Skipping...
# Processing Record 30 of set 11 | mgandu
# To get the XML File of all weather informations of the city named : [ mgandu ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=mgandu&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 31 of set 11 | punta alta
# To get the XML File of all weather informations of the city named : [ punta alta ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=punta alta&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 32 of set 11 | udaipur
# To get the XML File of all weather informations of the city named : [ udaipur ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=udaipur&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 33 of set 11 | borgarnes
# To get the XML File of all weather informations of the city named : [ borgarnes ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=borgarnes&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 34 of set 11 | bethel
# To get the XML File of all weather informations of the city named : [ bethel ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=bethel&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 35 of set 11 | harnosand
# To get the XML File of all weather informations of the city named : [ harnosand ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=harnosand&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
# Processing Record 36 of set 11 | point fortin
# To get the XML File of all weather informations of the city named : [ point fortin ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=point fortin&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 37 of set 11 | san carlos de bariloche
# To get the XML File of all weather informations of the city named : [ san carlos de bariloche ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=san carlos de bariloche&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 38 of set 11 | flin flon
# To get the XML File of all weather informations of the city named : [ flin flon ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=flin flon&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 39 of set 11 | omsukchan
# To get the XML File of all weather informations of the city named : [ omsukchan ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=omsukchan&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 40 of set 11 | batala
# To get the XML File of all weather informations of the city named : [ batala ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=batala&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 41 of set 11 | puri
# To get the XML File of all weather informations of the city named : [ puri ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=puri&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 42 of set 11 | hofn
# To get the XML File of all weather informations of the city named : [ hofn ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=hofn&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 43 of set 11 | narsaq
# To get the XML File of all weather informations of the city named : [ narsaq ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=narsaq&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 44 of set 11 | somerset
# To get the XML File of all weather informations of the city named : [ somerset ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=somerset&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 45 of set 11 | mosetse
# To get the XML File of all weather informations of the city named : [ mosetse ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=mosetse&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 46 of set 11 | wahiawa
# To get the XML File of all weather informations of the city named : [ wahiawa ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=wahiawa&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 47 of set 11 | bulungu
# To get the XML File of all weather informations of the city named : [ bulungu ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=bulungu&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 48 of set 11 | lumeje
# To get the XML File of all weather informations of the city named : [ lumeje ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=lumeje&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 49 of set 11 | strezhevoy
# To get the XML File of all weather informations of the city named : [ strezhevoy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=strezhevoy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 50 of set 11 | wageningen
# To get the XML File of all weather informations of the city named : [ wageningen ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=wageningen&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 1 of set 12 | kuusamo
# To get the XML File of all weather informations of the city named : [ kuusamo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kuusamo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 2 of set 12 | kovernino
# To get the XML File of all weather informations of the city named : [ kovernino ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=kovernino&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 3 of set 12 | brae
# To get the XML File of all weather informations of the city named : [ brae ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=brae&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 4 of set 12 | reo
# To get the XML File of all weather informations of the city named : [ reo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=reo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 5 of set 12 | labuhan
# To get the XML File of all weather informations of the city named : [ labuhan ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=labuhan&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 6 of set 12 | pontiac
# To get the XML File of all weather informations of the city named : [ pontiac ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=pontiac&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 7 of set 12 | sistranda
# To get the XML File of all weather informations of the city named : [ sistranda ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=sistranda&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 8 of set 12 | umba
# To get the XML File of all weather informations of the city named : [ umba ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=umba&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 9 of set 12 | ketchenery
# To get the XML File of all weather informations of the city named : [ ketchenery ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=ketchenery&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ ketchenery ] was not found. Skipping...
# Processing Record 9 of set 12 | richards bay
# To get the XML File of all weather informations of the city named : [ richards bay ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=richards bay&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 10 of set 12 | cumaribo
# To get the XML File of all weather informations of the city named : [ cumaribo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=cumaribo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# The City named [ cumaribo ] was not found. Skipping...
# Processing Record 10 of set 12 | dhidhdhoo
# To get the XML File of all weather informations of the city named : [ dhidhdhoo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=dhidhdhoo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 11 of set 12 | nosy varika
# To get the XML File of all weather informations of the city named : [ nosy varika ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=nosy varika&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
# Processing Record 12 of set 12 | marondera
# To get the XML File of all weather informations of the city named : [ marondera ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=marondera&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 13 of set 12 | shymkent
# To get the XML File of all weather informations of the city named : [ shymkent ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=shymkent&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 14 of set 12 | walvis bay
# To get the XML File of all weather informations of the city named : [ walvis bay ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=walvis bay&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 15 of set 12 | krasnoselkup
# To get the XML File of all weather informations of the city named : [ krasnoselkup ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=krasnoselkup&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 16 of set 12 | soyo
# To get the XML File of all weather informations of the city named : [ soyo ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=soyo&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# Processing Record 17 of set 12 | mirnyy
# To get the XML File of all weather informations of the city named : [ mirnyy ] is by clicking on the link: https://api.openweathermap.org/data/2.5/weather?q=mirnyy&appid=849cb715244fa751de756b3c473e27cf
# --------------------------------------------
#
# --------------------------------------------
#  Data Retrieval Complete
# --------------------------------------------

# %% [markdown]
# #### 4. Convert arrays of JSON into pandas dataframe.
# ##### We will export the cities Data into a csv File
# ##### We will display the DataFrame

# %%
#Creating our DataFrame Columns

weather_dict = {
        'City' : city_name,
        'Latitude' : Lat,
        'Longitude' : Lng,
        'Max Temperature' : Max_Temp,
        'Humidity' : Humidity,
        'Cloudiness' : Cloudiness,
        'Wind Speed' : Wind_Speed,
        'Country' : Country,
        'Date' : Date
        }

#Creating our DataFrame Based on 
cities_df = pd.DataFrame(weather_dict)

# %%
cities_df.head(10)
# Out:
#              City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 0           Kapaa   22.0752  -159.3190           295.33        83          20
# 1        Cherskiy   68.7500   161.3000           287.49        46         100
# 2          Beloha  -25.1667    45.0500           293.55        80           0
# 3       Cape Town  -33.9258    18.4232           296.55        35           0
# 4  Ribeira Grande   38.5167   -28.7000           294.37        78          40
# 5       Busselton  -33.6500   115.3333           289.52        82          26
# 6         Paamiut   61.9940   -49.6678           277.51        82          97
# 7      Codrington  -38.2667   141.9667           284.11        77         100
# 8      Bredasdorp  -34.5322    20.0403           295.46        28         100
# 9         Kumluca   36.3703    30.2869           298.44        67           1
#
#    Wind Speed Country        Date
# 0        5.66      US  1654961081
# 1        2.82      RU  1654961082
# 2        5.98      MG  1654961083
# 3        4.92      ZA  1654960842
# 4        3.09      PT  1654961084
# 5        3.85      AU  1654961085
# 6        3.59      GL  1654961087
# 7        8.57      AU  1654961087
# 8        0.95      ZA  1654961088
# 9        2.75      TR  1654960796

# %%
print(f"Our random Cities were about {len(cities_list)} city after the API process, we have only {len(cities_df)}, that means that {len(cities_list) - len(cities_df)} city was unable  for the API to find about it.")
# Out:
# Our random Cities were about 616 city after the API process, we have only 567, that means that 49 city was unable  for the API to find about it.

# %% [markdown]
# #### 5. Inspect the data and remove the cities where the humidity > 100%.

# %%
cities_df.count()
# Out:
# City               567
# Latitude           567
# Longitude          567
# Max Temperature    567
# Humidity           567
# Cloudiness         567
# Wind Speed         567
# Country            567
# Date               567
# dtype: int64

# %%
df_filtered = cities_df[cities_df["Humidity"]<=100]
df_filtered.count()
# Out:
# City               567
# Latitude           567
# Longitude          567
# Max Temperature    567
# Humidity           567
# Cloudiness         567
# Wind Speed         567
# Country            567
# Date               567
# dtype: int64

# %%
df_filtered
# Out:
#                City  Latitude  Longitude  Max Temperature  Humidity  \
# 0             Kapaa   22.0752  -159.3190           295.33        83
# 1          Cherskiy   68.7500   161.3000           287.49        46
# 2            Beloha  -25.1667    45.0500           293.55        80
# 3         Cape Town  -33.9258    18.4232           296.55        35
# 4    Ribeira Grande   38.5167   -28.7000           294.37        78
# ..              ...       ...        ...              ...       ...
# 562        Shymkent   42.3000    69.6000           300.48        24
# 563      Walvis Bay  -22.9575    14.5053           302.68        23
# 564   Krasnosel'kup   65.7000    82.4667           289.48        72
# 565            Soyo   -6.1349    12.3689           298.52        76
# 566           Mirny   62.5353   113.9611           279.95        81
#
#      Cloudiness  Wind Speed Country        Date
# 0            20        5.66      US  1654961081
# 1           100        2.82      RU  1654961082
# 2             0        5.98      MG  1654961083
# 3             0        4.92      ZA  1654960842
# 4            40        3.09      PT  1654961084
# ..          ...         ...     ...         ...
# 562          75        6.00      KZ  1654961609
# 563           0        3.60      NA  1654961610
# 564         100        6.82      RU  1654961611
# 565           2        4.87      AO  1654961612
# 566          83        3.13      RU  1654961612
#
# [567 rows x 9 columns]

# %% [markdown]
# #### 6. Get the indices of cities that have humidity over 100%.

# %%
df_filtered["Humidity"].max()
# Out:
# 100

# %%
df_filtered.describe()
# Out:
#          Latitude   Longitude  Max Temperature    Humidity  Cloudiness  \
# count  567.000000  567.000000       567.000000  567.000000  567.000000
# mean    21.987498   17.242226       293.614056   66.857143   54.252205
# std     33.796123   91.604571         8.636644   21.280452   38.364049
# min    -54.800000 -179.166700       270.690000    6.000000    0.000000
# 25%     -6.214950  -66.838600       287.320000   55.000000   17.500000
# 50%     26.588100   22.224700       295.160000   71.000000   59.000000
# 75%     51.011950   95.447600       299.980000   82.000000   97.000000
# max     78.218600  179.316700       316.810000  100.000000  100.000000
#
#        Wind Speed          Date
# count  567.000000  5.670000e+02
# mean     3.609418  1.654961e+09
# std      2.407583  1.630566e+02
# min      0.000000  1.654961e+09
# 25%      1.760000  1.654961e+09
# 50%      3.130000  1.654961e+09
# 75%      4.940000  1.654961e+09
# max     14.860000  1.654962e+09

# %% [markdown]
# #### 7. Make a new DataFrame equal to the city data to drop all humidity outliers by index. ?
# #### Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
df_filtered = cities_df[cities_df["Humidity"] < 100]

df_filtered = pd.DataFrame(
    {
        'City' : city_name,
        'Latitude' : Lat,
        'Longitude' : Lng,
        'Max Temperature' : Max_Temp,
        'Humidity' : Humidity,
        'Cloudiness' : Cloudiness,
        'Wind Speed' : Wind_Speed,
        'Country' : Country,
        'Date' : Date
})

# %%
df_filtered.columns
# Out:
# Index(['City', 'Latitude', 'Longitude', 'Max Temperature', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %% [markdown]
# #### 8. Export city data into csv

# %%
cleaned_cities_file = "Clean_City_Data.csv"
df_filtered.to_csv(os.path.join(folder_path,'output_data',cleaned_cities_file), index_label = "clean_city_data")

# %% [markdown]
# # Plotting The Data
#
# #### a. Build a scatterplot for City Latitude vs. Temperature using matplotlib.pyplot.

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
# Save the figure
# Show plot
fig = plt.figure(1, figsize=[12, 9])
scat_lat = df_filtered["Latitude"]
scat_temp = df_filtered["Max Temperature"]

plt.scatter(scat_lat,scat_temp,marker='o', facecolor='steelblue', edgecolor='black',s=50, alpha=0.75, linewidth=1)
plt.title('City Latitude vs. Max Temperature (Current)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.tight_layout()
plt.savefig(os.path.join(folder_path,'output_data','lat_temp'))
plt.show()

# %% [markdown]
# ### Interpretation : We can say that the emperature is inversely related to latitude. As latitude increases, the temperature falls, and vice versa. Generally, around the world, it gets warmer towards the equator and cooler towards the poles.

# %% [markdown]
# #### b. Build a scatterplot for City Latitude vs. Humidity using matplotlib.pyplot.

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
# Save the figure
# Show plot

fig = plt.figure(1, figsize=[12, 9])
scat_lat = df_filtered["Latitude"]
scat_hum = df_filtered["Humidity"]

plt.scatter(scat_lat,scat_hum,marker='o', facecolor='steelblue', edgecolor='black',s=50, alpha=0.75, linewidth=1)
plt.title('City Latitude vs. Humidity (Current)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.tight_layout()
plt.savefig(os.path.join(folder_path,'output_data','lat_hum'))
plt.show()

# %% [markdown]
# ### Interpretation : We can say that Humidity depends on Latitude and there's a higher correlation as when latitude increaser, the humidity increases and vice versa. is inversely related to latitude. As latitude increases, the temperature falls, and vice versa. Generally, around the world, it gets warmer towards the equator and cooler towards the poles.

# %% [markdown]
# #### c. Build a scatterplot for City Latitude vs. Cloudiness using matplotlib.pyplot.

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
# Save the figure
# Show plot

fig = plt.figure(1, figsize=[12, 9])
scat_lat = df_filtered["Latitude"]
scat_cloud = df_filtered["Cloudiness"]

plt.scatter(scat_lat,scat_cloud, marker='o', facecolor='steelblue', edgecolor='black', s=50, alpha=0.75, linewidth=1)
plt.title('City Latitude vs. Cloudiness (Current)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.tight_layout()
plt.savefig(os.path.join(folder_path,'output_data','lat_cloud'))
plt.show()

# %% [markdown]
# ### Interpretation : As latitude increases the intensity of the solar energy that strikes an area decreases and climates become cooler so more clouds. … The higher the elevation the colder the air and therefore the colder the climate

# %% [markdown]
# #### Build a scatterplot for City Latitude vs. Wind Speed using matplotlib.pyplot.

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
# Save the figure
# Show plot

fig = plt.figure(1, figsize=[12, 9])
scat_lat = df_filtered["Latitude"]
scat_wind_speed = df_filtered["Wind Speed"]

plt.scatter(scat_lat,scat_wind_speed, marker='o', facecolor='steelblue', edgecolor='black', s=50, alpha=0.75, linewidth=1)
plt.title('City Latitude vs. Wind Speed (Current)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.tight_layout()
plt.savefig(os.path.join(folder_path,'output_data','lat_wind_speed'))

# %% [markdown]
# ### Interpretation : We can say that cities that are near to the equator are characterized by low winds,  while mid-latitudes experience much faster airflow.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# #### a. We will create a function that can be able to develop a Linear Regression plots.

# %%
def plot_metric_with_linear_regression(figure_number,name_image,x_series, y_series, x_label, y_label, title):
    fig = plt.figure(figure_number, figsize=[12, 9])
    plt.scatter(x_series,y_series)
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_series, y_series)
    regress_values = x_series * slope + intercept
    plt.plot(x_series,regress_values,"r-")
    annotate_x = x_series.mean()
    annotate_y = annotate_x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq,(annotate_x,annotate_y),color="red",fontsize=20,fontweight="bold")
    plt.annotate(f"r={rvalue:.2f}",(x_series.min(),y_series.min()),color="red",fontsize=20,fontweight="bold")
    plt.grid()
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.savefig(os.path.join(folder_path,'output_data',name_image))
    plt.show()
    return plt

# %% [markdown]
# #### b. Create Northern and Southern Hemisphere DataFrames

# %%
northlat_df = df_filtered.loc[df_filtered["Latitude"] >= 0,:]
southlat_df = df_filtered.loc[df_filtered["Latitude"] < 0,:]

# %%
# Flip the negative sign of the southern latitudes, to indicate distance away from the equator
southlat_df["Latitude"] *= -1
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_16380\1320732964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southlat_df["Latitude"] *= -1

# %%
northlat_df.head()
# Out:
#              City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 0           Kapaa   22.0752  -159.3190           295.33        83          20
# 1        Cherskiy   68.7500   161.3000           287.49        46         100
# 4  Ribeira Grande   38.5167   -28.7000           294.37        78          40
# 6         Paamiut   61.9940   -49.6678           277.51        82          97
# 9         Kumluca   36.3703    30.2869           298.44        67           1
#
#    Wind Speed Country        Date
# 0        5.66      US  1654961081
# 1        2.82      RU  1654961082
# 4        3.09      PT  1654961084
# 6        3.59      GL  1654961087
# 9        2.75      TR  1654960796

# %%
southlat_df.head()
# Out:
#          City  Latitude  Longitude  Max Temperature  Humidity  Cloudiness  \
# 2      Beloha   25.1667    45.0500           293.55        80           0
# 3   Cape Town   33.9258    18.4232           296.55        35           0
# 5   Busselton   33.6500   115.3333           289.52        82          26
# 7  Codrington   38.2667   141.9667           284.11        77         100
# 8  Bredasdorp   34.5322    20.0403           295.46        28         100
#
#    Wind Speed Country        Date
# 2        5.98      MG  1654961083
# 3        4.92      ZA  1654960842
# 5        3.85      AU  1654961085
# 7        8.57      AU  1654961087
# 8        0.95      ZA  1654961088

# %% [markdown]
# #### Use function to plot Max Temp vs. Latitude Linear Regression for northern and southern hemisphere

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Max Temperature"]

name_image = "northerntemplat.png"
plt = plot_metric_with_linear_regression(5,name_image,x_values, y_values,"Latitude", "Temperature (Farenheit)", "Maximum Temperature v. Northern Latitudes")

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Max Temperature"]
name_image = "southerntemplat.png"
plt = plot_metric_with_linear_regression(6,name_image,x_values, y_values,"Latitude", "Temperature (Farenheit)", "Maximum Temperature v. Southern Latitudes")

# %% [markdown]
# ### Interpretation : We can say that The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# #### Use function to plot Humidity (%) vs. Latitude Linear Regression for northern and southern hemisphere.

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Humidity"]
name_image = "northernhumlat.png"
plt = plot_metric_with_linear_regression(7,name_image,x_values, y_values,"Latitude", "Humidity (%)", "Humidity v. Northern Latitudes")

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Humidity"]
name_image = "sotuhernhumlat.png"
plt = plot_metric_with_linear_regression(8,name_image,x_values, y_values,"Latitude", "Humidity (%)", "Humidity v. Southern Latitudes")

# %% [markdown]
# ### Interpretation : We can say that The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# #### Use function to plot Cloudiness (%) vs. Latitude Linear Regression for northern and southern hemisphere.

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Cloudiness"]
name_image = "northerncloudlat.png"
plt = plot_metric_with_linear_regression(9,name_image,x_values, y_values,"Latitude", "Cloudiness (%)", "Cloudiness v. Northern Latitudes")

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Cloudiness"]
name_image = "southerncloudlat.png"
plt = plot_metric_with_linear_regression(10,name_image,x_values, y_values,"Latitude", "Cloudiness (%)", "Cloudiness v. Sourthern Latitudes")

# %% [markdown]
# ### Interpretation : We can cay that The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# #### Use function to plot Wind Speed (mph) vs. Latitude Linear Regression for northern and southern hemisphere.

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Wind Speed"]

name_image = "northernwindlat.png"
plt = plot_metric_with_linear_regression(11,name_image,x_values, y_values,"Latitude", "Wind Speed (mph)", "Wind Speed v. Northern Latitudes")

# %% [markdown]
# ##### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Latitude"]
y_values = southlat_df["Wind Speed"]

name_image = "southernwindlat.png"
plt = plot_metric_with_linear_regression(12,name_image,x_values, y_values,"Latitude", "Wind Speed (mph)", "Wind Speed v. Southern Latitudes")

# %% [markdown]
# ### Interpretation : We can say that The low r values indicate that there is no real relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.
